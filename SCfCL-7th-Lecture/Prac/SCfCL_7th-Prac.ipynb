# %% [markdown]
# # コンピュータリテラシ発展 第7回 課題
#
# 今回の課題は**OpenPyXLを使ってExcelファイルにグラフを作成する**問題が3問です．

# %% [markdown]
# ## 注意事項
#
# Excelを作成してそのExcelファイルを編集します．
# そのため，**問題ごとに保存するファイル名を変更してください**．
# 提出は，**ipynbと各問題で保存したExcelファイル（合計4ファイル）**を提出してください．
#
# このノートブックは，授業中に作成したフォルダを利用してください．

# %% [markdown]
# ## ライブラリをインポート
# 各自必要と思うライブラリやメソッドなどをインポートしてください．

# %% [markdown]
# ## 問題1：世界の労働時間グラフ
#
# Moodleから「**workinghours.xlsx**」をダウンロードしてColabにアップしてください．
# 以下の指示に従ってグラフを作成してください．
# - 元データ：C3〜C44
# - グラフの種類：棒グラフ
# - グラフタイトル：労働時間
# - 系列名：各国
# - グラフ貼り付け位置セル：E3
#
# ### 実行結果例
#
# ![](https://github.com/shimizu-sit/2024-SIT-1st-SCfCL/blob/main/SCfCL-7th-Lecture/Prac/SCfCL-7th-Prac-1-example.png?raw=true)

# %% [markdown]
# ## 問題2：Excelファイルの作成とデータ準備
#
# 新規にExcelファイルを作成してください．
# 以下の指示に従ってExcelファイルにデータを作成してください．
#
# - B2セル：「角度」，C3セル「SIN」
# - B3セル〜B27セルに0〜360まで15刻みで数値入れる
# - C3セル〜C27セルにB3セル〜B27セルの値を受け取りSINの値を入力
#
# ### 実行例
#
# ![](https://github.com/shimizu-sit/2024-SIT-1st-SCfCL/blob/main/SCfCL-7th-Lecture/Prac/SCfCL-7th-Prac-2-example.png?raw=true)

# %% [markdown]
# ## 問題3：棒グラフでSINグラフを作成
#
# 問題2で作成したExcelファイルを読み込んでください．以下の指示に従ってグラフを作成してください．
#
# - 元データ：セルC3〜C27
# - グラフの種類：棒グラフ
# - グラフタイトル：三角関数
# - 系列名：sin()
# - グラフ貼り付け位置セル：E3
#
# ### 実行例
#
# ![](https://github.com/shimizu-sit/2024-SIT-1st-SCfCL/blob/main/SCfCL-7th-Lecture/Prac/SCfCL-7th-Prac-3-example.png?raw=true)
